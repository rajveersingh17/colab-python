# %% [markdown]
# <a href="https://colab.research.google.com/github/rajveersingh17/colab-python/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("day6")
# Out:
# day6

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Open and read a file
data = open('/content/drive/MyDrive/hello.txt', 'r')

print(data.read())

data.close()
# Out:
# Mounted at /content/drive
# hi

# %%
# write and read

data2 = open("/content/drive/MyDrive/hello.txt", "w")
data2.write("we are indians")
data2.close()

data2 = open("/content/drive/MyDrive/hello.txt", "r")
print(data2.read())
data2.close()
# Out:
# we are indians

# %%
#NUMPY

# %%
import numpy as np

# 1D array
l = np.array([10, 20, 30, 40])

print(l * 2)
# Out:
# [20 40 60 80]

# %%
import numpy as np

arr = np.array([1, 2, 3, 4])

print(arr)
print(arr[0])
print(arr[-1])
# Out:
# [1 2 3 4]
# 1
# 4

# %%
import numpy as np

# check type
l = [10, 20, 30, 40]

print(l)
print(type(l))

arr = np.array(l)

print(arr)
print(type(arr))
# Out:
# [10, 20, 30, 40]
# <class 'list'>
# [10 20 30 40]
# <class 'numpy.ndarray'>

# %%
# value add = 2

import numpy as np

l = [10, 20, 30, 40]

# print(l + 2)  # add not acceptable with list

arr = np.array(l)

print(arr + 2)
# Out:
# [12 22 32 42]

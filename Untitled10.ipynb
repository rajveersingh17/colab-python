# %% [markdown]
# <a href="https://colab.research.google.com/github/rajveersingh17/colab-python/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
print("day10")
# Out:
# day10

# %%
# pd is nickname of pandas
import pandas as pd
l = [10,20,30,40,50] # list
df = pd.Series(l) # use list in pd
print(df)


# example data
df = pd.Series(data=l)
print(df)

# example index
df = pd.Series(data=l , index=['nikhil','devendra','raj','hello','unknown'])
print(df)

# example key = index | value = value
d = {'nikhil':10,'devendra':20,'raj':30,'hello':40,'unknown':50}
df = pd.Series(data=d)
print(df)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# nikhil      10
# devendra    20
# raj         30
# hello       40
# unknown     50
# dtype: int64
# nikhil      10
# devendra    20
# raj         30
# hello       40
# unknown     50
# dtype: int64

# %%
import pandas as pd
data = [['devendra',10],['nikhil',20],['raj',30],['hello',40]]
df = pd.DataFrame(data)
print(df)

# add cols name
df = pd.DataFrame(data,columns=['name','age'])
print(df)


# add indexing name
df = pd.DataFrame(data,index=['a','b','c','d'])
print(df)
# Out:
#           0   1
# 0  devendra  10
# 1    nikhil  20
# 2       raj  30
# 3     hello  40
#        name  age
# 0  devendra   10
# 1    nikhil   20
# 2       raj   30
# 3     hello   40
#           0   1
# a  devendra  10
# b    nikhil  20
# c       raj  30
# d     hello  40

# %%
# github csv
import pandas as pd
url = "https://raw.githubusercontent.com/rajveersingh17/colab-python/main/file.csv"
df = pd.read_csv(url)
print(df)
# Out:
#        name gender
# 0    nikhil   male
# 1       raj   male
# 2  devendra   male
# 3     hello   male

# %%
# github
import pandas as pd
url = "https://raw.githubusercontent.com/rajveersingh17/colab-python/main/data.json"
df = pd.read_csv(url)
print(df)
# Out:
#                                            {
#     "name":["nikhil" devendra raj hello] NaN
#     "age":[10        20       30  40]    NaN
# }                    NaN      NaN NaN    NaN

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/rajveersingh17/colab-python/main/file.xlsx"
df = pd.read_excel(url)
print(df)
# Out:
#        name gender
# 0    nikhil   male
# 1       raj   male
# 2  devendra   male
# 3     hello   male

# %%
# excel file
import pandas as pd
url = "https://raw.githubusercontent.com/rajveersingh17/colab-python/main/file.xlsx"
df = pd.read_excel(url)
print(df)
#excel file export
df.to_excel("file1.xlsx", index=False)


# json file
url = "https://raw.githubusercontent.com/rajveersingh17/colab-python/main/data.json"
df1 = pd.read_json(url)
print(df1)
#json file export
df1.to_json("file2.json")
# Out:
#        name gender
# 0    nikhil   male
# 1       raj   male
# 2  devendra   male
# 3     hello   male
#        name  age
# 0    nikhil   10
# 1  devendra   20
# 2       raj   30
# 3     hello   40

# %% [markdown]
# <a href="https://colab.research.google.com/github/rajveersingh17/colab-python/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("rajveer singh")
# Out:
# rajveer singh

# %%
# variable
num = 10
print(num)
print(id(num))
print(type(num))

num1 = 10
print(num1)
print(id(num1))
# Out:
# 10
# 11645640
# <class 'int'>
# 10
# 11645640

# %%
#string
text = "Hello"
print(text)
print(id(text))
print(type(text))
# Out:
# Hello
# 133451223403520
# <class 'str'>

# %%
#boolean
flag = True
print(flag)
print(id(flag))
print(type(flag))
# Out:
# True
# 10549600
# <class 'bool'>

# %%
#float
num = 10.5
print(num)
print(id(num))
print(type(num))
# Out:
# 10.5
# 133450679527984
# <class 'float'>

# %%
roll_no = input("enter your roll no: ")

print(roll_no)
print(id(roll_no))
print(type(roll_no))
# Out:
# enter your roll no: 234566
# 234566
# 133450677092688
# <class 'str'>

# %%
name = input("Enter your name: ")

print(name)
print(id(name))
print(type(name))
# Out:
# Enter your name: rajveder singh
# rajveder singh
# 133450676073712
# <class 'str'>

# %%
marks = float(input("Enter your marks: "))

print(marks)
print(id(marks))
print(type(marks))
# Out:
# Enter your marks: 98
# 98.0
# 133450679533072
# <class 'float'>

# %%
value = input("Enter True/False: ").strip().lower()

bool_value = value == "true"

print(bool_value)
print(id(bool_value))
print(type(bool_value))
# Out:
# Enter True/False: true
# True
# 10549600
# <class 'bool'>

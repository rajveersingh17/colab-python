# %% [markdown]
# <a href="https://colab.research.google.com/github/rajveersingh17/colab-python/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("rajveer singh")
# Out:
# rajveer singh

# %%
# arithmetic opr

num1 = 10
num2 = 20

print(num1 + num2)
# Out:
# 30

# %%
# arithmetic operators

num1 = 20
num2 = 10
print("addition")
print(num1 + num2)
print("subtraction")
print(num1 - num2)
print("multiple")
print(num1 * num2)
print("division")
print(num1 / num2)
print("modulus")
print(num1 % num2)
print("power")
print(num1 ** 2)
print("floor division")
print(num1 // 3)
# Out:
# addition
# 30
# subtraction
# 10
# multiple
# 200
# division
# 2.0
# modulus
# 0
# power
# 400
# floor division
# 6

# %%
num1 = 10
num2 = 20

print(num1 < num2)
# Out:
# True

# %%
num1 = 10
num2 = 10

print(num1 >= num2)
# Out:
# True

# %%
num1 = 19
num2 = 25

print(num1 > num2)
print(num1 < num2)
print(num1 == num2)
print(num1 != num2)
print(num1 >= num2)
print(num1 <= num2)
# Out:
# False
# True
# False
# True
# False
# True

# %%
print("assigement opr")
# Out:
# assigement opr

# %%
num1 = 10
num2 = 20

num1 += num2

print(num1)
# Out:
# 30

# %%
num1 = 20
num2 = 5

num1 -= num2

print(num1)
# Out:
# 15

# %%
num1 = 10
num2 = 5

num1 *= num2

print(num1)
# Out:
# 50

# %%
num1 = 20
num2 = 5

num1 /= num2

print(num1)
# Out:
# 4.0

# %%
num1 = 22
num2 = 5

num1 %= num2

print(num1)
# Out:
# 2

# %%
print("logical opr")
# Out:
# logical opr

# %%
# logical operators

age = 20
marks = 75
attendance = 85

print(age >= 18 and marks >= 40)
print(age >= 18 and attendance >= 90)

print(marks >= 80 or attendance >= 80)
print(age < 18 or marks >= 40)

print(not(age < 18))
print(not(marks < 40))

num1 = 10
num2 = 20
num3 = 0

print(num1 and num2)
print(num1 or num2)

print(num3 and num2)
print(num3 or num2)

print(not num3)

result = age >= 18 and marks >= 40 and attendance >= 75
print(result)
# Out:
# True
# False
# True
# True
# True
# True
# 20
# 10
# 0
# 20
# True
# True

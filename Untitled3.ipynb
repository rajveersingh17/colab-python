# %% [markdown]
# <a href="https://colab.research.google.com/github/rajveersingh17/colab-python/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("day3")
# Out:
# day3

# %%
marks = int(input("Enter marks: "))
if marks >= 95:
    print("Grade A")
elif marks >= 90:
    print("Grade B")
elif marks >= 75:
    print("Grade C")
elif marks >= 60:
    print("Grade D")
else:
    print("Fail")
# Out:
# Enter marks: 39
# Fail

# %%
d = {"age": 20, "name": "rajveer"}

print(d["age"])
print(d["name"])
# Out:
# 20
# rajveer

# %%
d = {"users":["nikhil","raj"]}
print(d['users'])
print(d['users'][0])
print(d['users'][1])
# Out:
# ['nikhil', 'raj']
# nikhil
# raj
